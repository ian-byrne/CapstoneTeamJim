# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

import sklearn.metrics
from sklearn.model_selection import GridSearchCV

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
# render plot in default browser
pio.renderers.default = 'browser'

from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# %% [markdown]
# ### Reading in data with raw values and adding GDP
# This mainly applies to Redfin data- rather than a percentage use the raw numbers

# %%
data = pd.read_pickle('dataraw_to2018.pkl')
gdp = pd.read_csv('GDP.csv')

gdp.head()
# Out:
#          DATE      GDP
# 0  1947-01-01  243.164
# 1  1947-04-01  245.968
# 2  1947-07-01  249.585
# 3  1947-10-01  259.745
# 4  1948-01-01  265.742

# %%
gdp['year'] = gdp['DATE'].apply(lambda x: x[:4])
gdp['month'] = gdp['DATE'].apply(lambda x: x[5:7])
gdp.head()
# Out:
#          DATE      GDP  year month
# 0  1947-01-01  243.164  1947    01
# 1  1947-04-01  245.968  1947    04
# 2  1947-07-01  249.585  1947    07
# 3  1947-10-01  259.745  1947    10
# 4  1948-01-01  265.742  1948    01

# %%
gdp = gdp[gdp['month']=='10']

# %%
gdp = gdp[['year', 'GDP']]
gdp['year'] = gdp['year'].apply(lambda x: int(x))

# %%
data.shape
# Out:
# (3072, 79)

# %%
data = data.merge(gdp, on='year', how='left')

# %% [markdown]
# ### Train/Test/Val
# Split data through 2018 into X and y then split 75/25 train/test. 2019 later is used as validation.

# %%
X = data.iloc[:,3:-2].join(data.iloc[:,-1])
y = data.iloc[:,-2:-1]

# %%
#X_norm = StandardScaler().fit_transform(X)
X_norm = X
X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Model Training and Selection
# Extra Trees Regressor returns the best R2 on test and validation data

# %%
regr = RandomForestRegressor(max_depth=10, random_state=0)
regr.fit(X_train, y_train)
# Out:
# /var/folders/j2/51tvlt7n02xc69lkwdrbspqw0000gn/T/ipykernel_11968/2848552734.py:2: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(max_depth=10, random_state=0)

# %%
score = regr.score(X_test, y_test)
print("Random Forest Regressor Test score: "+str(score)+'\n')

##0.5669654667807917
# Out:
# Random Forest Regressor Test score: 0.566822295903957

# %%
# parameters = {'n_estimators': [100, 500, 1000],
#                 'max_depth':[5, 10, 15], 
#                 'max_features': ['auto', 'sqrt', 'log2'],
#                 'bootstrap': [True, False]}
# model = RandomForestRegressor()
# grid = GridSearchCV(model, parameters)
# grid.fit(X, y)

# %%
# grid.cv_results_

# %%
# grid.best_estimator_

## RandomForestRegressor(bootstrap=False, max_depth=15, max_features='sqrt',
 ##                     n_estimators=1000)

# %%
regr = RandomForestRegressor(bootstrap=False, max_depth=15, 
                                max_features='sqrt', n_estimators=1000,
                                random_state=0)
regr.fit(X_train, y_train)
# Out:
# /var/folders/j2/51tvlt7n02xc69lkwdrbspqw0000gn/T/ipykernel_11968/2106608459.py:4: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=False, max_depth=15, max_features='sqrt',
#                       n_estimators=1000, random_state=0)

# %%
score = regr.score(X_test, y_test)
print("Random Forest Regressor Test score: "+str(score)+'\n')

##0.5554493055329761
# Out:
# Random Forest Regressor Test score: 0.5552637737365926

# %%
##try extra trees regressor
from sklearn.ensemble import ExtraTreesRegressor
et = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(
       X_train, y_train)
et.score(X_test, y_test)

## 0.6272394296098471
# Out:
# /var/folders/j2/51tvlt7n02xc69lkwdrbspqw0000gn/T/ipykernel_11968/4119476172.py:3: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.6284935346003326

# %%
# parameters = {'n_estimators': [100, 500, 1000],
#                 'max_depth':[5, 10, 15], 
#                 'max_features': ['auto', 'sqrt', 'log2'],
#                 'bootstrap': [True, False]}
# model = ExtraTreesRegressor()
# grid_et = GridSearchCV(model, parameters)
# grid_et.fit(X, y)
# Out:
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# ...
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/jennyney/Dev/Capstone/capstone_git/capstone_env_v2/lib/python3.8/site-packages/sklearn/model_selection/_search.py:765: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# GridSearchCV(estimator=ExtraTreesRegressor(),
#              param_grid={'bootstrap': [True, False], 'max_depth': [5, 10, 15],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 500, 1000]})

# %%
grid_et.best_estimator_

##ExtraTreesRegressor(max_depth=15, n_estimators=500)
# Out:
# ExtraTreesRegressor(bootstrap=True, max_depth=15, n_estimators=1000)

# %%
# et = ExtraTreesRegressor(n_estimators=500, max_depth=15, random_state=0).fit(
#        X_train, y_train)
et = ExtraTreesRegressor(max_depth=15, n_estimators=500, random_state=0).fit(
       X_train, y_train)

et.score(X_test, y_test)

## 0.6294494812587801
# Out:
# /var/folders/j2/51tvlt7n02xc69lkwdrbspqw0000gn/T/ipykernel_11968/198603156.py:3: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.6294600060880793

# %%
df2019 = pd.read_pickle('dataraw_2019.pkl')
df2019.head()
# Out:
#    state_fips county_fips  year  debt_ratio_low  debt_ratio_high  \
# 0         1.0       01015  2019          1.2800            1.475
# 1         1.0       01043  2019          1.6400            1.905
# 2         1.0       01049  2019          1.1450            1.325
# 3         1.0       01055  2019          1.5275            1.760
# 4         1.0       01073  2019          0.8950            1.100
#
#    corp_income_tax_low  corp_income_tax_high  income_tax_low  income_tax_high  \
# 0                  6.5                   6.5             2.0              5.0
# 1                  6.5                   6.5             2.0              5.0
# 2                  6.5                   6.5             2.0              5.0
# 3                  6.5                   6.5             2.0              5.0
# 4                  6.5                   6.5             2.0              5.0
#
#    11_avg_annual_employee_pct_chg  ...  hs_diploma_pct  \
# 0                        0.000000  ...        0.197808
# 1                        0.000000  ...        0.162496
# 2                      100.000000  ...        0.196132
# 3                        0.000000  ...        0.179714
# 4                        1.408451  ...        0.156648
#
#    some_college_lessthan_1yr_pct  some_college_greaterthan_1yr_pct  \
# 0                       0.036301                          0.115479
# 1                       0.055355                          0.109779
# 2                       0.048131                          0.072840
# 3                       0.061202                          0.117769
# 4                       0.038477                          0.105712
#
#    bachelor_degree_pct  master_degree_pct  professional_degree_pct  \
# 0             0.079944           0.034479                 0.009471
# 1             0.070850           0.033366                 0.004083
# 2             0.051641           0.029072                 0.003174
# 3             0.073571           0.030176                 0.009074
# 4             0.139755           0.061027                 0.023885
#
#    doctorate_degree_pct  occupied_units_pct  vacant_units_pct  \
# 0              0.010404            0.829527          0.170473
# 1              0.002017            0.838823          0.161177
# 2              0.000000            0.787192          0.212808
# 3              0.008126            0.836966          0.163034
# 4              0.012866            0.854944          0.145056
#
#    annual_change_pct
# 0               3.43
# 1               4.19
# 2               4.22
# 3               3.60
# 4               3.75
#
# [5 rows x 79 columns]

# %%
gdp['GDP'][gdp['year']==2019]
# Out:
# 291    21694.458
# Name: GDP, dtype: float64

# %%
df2019['GDP'] = 21694.458

# %%
#X_val = StandardScaler().fit_transform(df2019.iloc[:,3:-2].join(df2019.iloc[:,-1]))
X_val = df2019.iloc[:,3:-2].join(df2019.iloc[:,-1])
y_val = df2019.iloc[:,-2:-1]

# %%
score = regr.score(X_val, y_val)
print("Random Forest Regressor Validation score: "+str(score)+'\n')

## -0.16832835442893224
# Out:
# Random Forest Regressor Validation score: -0.06228040267627066

# %%
et.score(X_val, y_val)

## -0.00022179764539975722
##no scaler == 0.2589469340774412
# Out:
# 0.2589469340774412

# %%
d = dict()
for i, j in zip(X.columns, regr.feature_importances_):
    d[i]=j

print({k: v for k, v in sorted(d.items(), key=lambda item: item[1])})
#print(et.feature_importances_)
# Out:
# {'21_avg_annual_pay_pct_chg': 0.0036844771224022774, 'birth_45_50_pct': 0.004026009276510636, '21_avg_annual_employee_pct_chg': 0.004152944048024643, '11_avg_annual_pay_pct_chg': 0.004405767621757717, '11_avg_annual_employee_pct_chg': 0.004811253297107085, 'birth_15_19_pct': 0.00489752956793322, '99_avg_annual_pay_pct_chg': 0.00509643810051376, '42_avg_annual_pay_pct_chg': 0.005269327612092776, '71_avg_annual_pay_pct_chg': 0.005314067918365244, '55_avg_annual_pay_pct_chg': 0.00536570865108804, '22_avg_annual_employee_pct_chg': 0.005426338148432276, '22_avg_annual_pay_pct_chg': 0.00543219148660849, '62_avg_annual_pay_pct_chg': 0.005438256432847808, '81_avg_annual_pay_pct_chg': 0.005494735667695048, '56_avg_annual_employee_pct_chg': 0.00556315523880675, '54_avg_annual_pay_pct_chg': 0.005570140144384466, '53_avg_annual_employee_pct_chg': 0.005638710575002025, '52_avg_annual_pay_pct_chg': 0.0056908932913927405, '55_avg_annual_employee_pct_chg': 0.005720177431246267, '51_avg_annual_pay_pct_chg': 0.005773420323001327, '61_avg_annual_pay_pct_chg': 0.005865879758447069, 'birth_40_44_pct': 0.005920347444313096, '71_avg_annual_employee_pct_chg': 0.005929405080749104, '56_avg_annual_pay_pct_chg': 0.0061319778550388785, '42_avg_annual_employee_pct_chg': 0.006444885625401319, '61_avg_annual_employee_pct_chg': 0.0064535374717500475, '23_avg_annual_pay_pct_chg': 0.006467628254043224, '92_avg_annual_pay_pct_chg': 0.006472948054420702, '53_avg_annual_pay_pct_chg': 0.0066099376949604926, '72_avg_annual_pay_pct_chg': 0.006638995865651444, '51_avg_annual_employee_pct_chg': 0.006719449076598604, 'birth_30_34_pct': 0.007266455267883655, 'birth_35_39_pct': 0.007606096040849116, '92_avg_annual_employee_pct_chg': 0.007622286933438309, '99_avg_annual_employee_pct_chg': 0.007912680100654039, '52_avg_annual_employee_pct_chg': 0.007959556537011225, 'birth_25_29_pct': 0.008007276552023662, 'professional_degree_pct': 0.008320907737070971, '81_avg_annual_employee_pct_chg': 0.008568174243457452, 'birth_20_24_pct': 0.008583144792554457, '62_avg_annual_employee_pct_chg': 0.008589023311887255, 'doctorate_degree_pct': 0.010250033282948936, 'debt_ratio_high': 0.010302008980710712, 'travel_time_to_work': 0.010458418083531044, 'household_income': 0.01076000251446351, 'bachelor_degree_pct': 0.011042749794079291, 'debt_ratio_low': 0.011086230115570679, 'population': 0.011149704030785653, '54_avg_annual_employee_pct_chg': 0.011228453486327101, 'hs_diploma_pct': 0.011328529999843111, 'inventory': 0.011807050632133567, 'vacant_units_pct': 0.013164906068429185, 'occupied_units_pct': 0.013553507978307188, 'home_value_median': 0.014647504103215478, '72_avg_annual_employee_pct_chg': 0.015806239872405228, 'some_college_lessthan_1yr_pct': 0.016223268237493687, 'master_degree_pct': 0.01679087386148912, 'new_listings': 0.017017133141907462, 'grade12_nodiploma_pct': 0.017286605445719687, 'vehicles_per_person': 0.017314783217608463, 'median_list_ppsf': 0.017535791884959465, 'median_ppsf': 0.017844029179556194, '23_avg_annual_employee_pct_chg': 0.019123146341210245, 'median_sale_price': 0.019697730828709743, 'homes_sold': 0.02053953197863854, 'median_list_price': 0.023287980736412875, 'GDP': 0.024385556483239864, 'corp_income_tax_low': 0.025407763815114788, 'some_college_greaterthan_1yr_pct': 0.02758666893148465, 'sold_above_list': 0.027631912518558836, 'income_tax_low': 0.033778356083923676, 'avg_sale_to_list': 0.03400893678122613, 'corp_income_tax_high': 0.041293759495773, 'median_dom': 0.04298841799422079, 'income_tax_high': 0.04985867119721606, 'months_of_supply': 0.07095160724936922}

# %%
d = dict()
for i, j in zip(X.columns, et.feature_importances_):
    d[i]=j

print({k: v for k, v in sorted(d.items(), key=lambda item: item[1])})
# Out:
# {'21_avg_annual_pay_pct_chg': 0.0028170402529790555, '11_avg_annual_pay_pct_chg': 0.0030687587988049362, '62_avg_annual_pay_pct_chg': 0.0031788900370751457, '61_avg_annual_pay_pct_chg': 0.0034122837620939642, '61_avg_annual_employee_pct_chg': 0.003499749383355173, '21_avg_annual_employee_pct_chg': 0.0036522751264605044, '22_avg_annual_employee_pct_chg': 0.0037246175511805564, '81_avg_annual_pay_pct_chg': 0.0037676379217616764, '71_avg_annual_pay_pct_chg': 0.0039113932413558155, '51_avg_annual_pay_pct_chg': 0.004101866353943255, '11_avg_annual_employee_pct_chg': 0.004130450372875946, '54_avg_annual_pay_pct_chg': 0.004250340850481281, '22_avg_annual_pay_pct_chg': 0.0042581017377707146, '55_avg_annual_employee_pct_chg': 0.004305053314657646, '92_avg_annual_pay_pct_chg': 0.004421059732738451, '23_avg_annual_pay_pct_chg': 0.004500195144466099, '56_avg_annual_pay_pct_chg': 0.004518483546963503, '71_avg_annual_employee_pct_chg': 0.004602349059357196, '51_avg_annual_employee_pct_chg': 0.004620169278200421, '52_avg_annual_pay_pct_chg': 0.004663674437973781, '92_avg_annual_employee_pct_chg': 0.004750998584909813, '42_avg_annual_pay_pct_chg': 0.004778951267062551, '56_avg_annual_employee_pct_chg': 0.00479403391718533, '54_avg_annual_employee_pct_chg': 0.0048583677572998085, '42_avg_annual_employee_pct_chg': 0.004864086173647557, '55_avg_annual_pay_pct_chg': 0.004874676184654547, '72_avg_annual_pay_pct_chg': 0.004974903756852244, '53_avg_annual_employee_pct_chg': 0.004992448385031284, '99_avg_annual_pay_pct_chg': 0.005286927434333274, '52_avg_annual_employee_pct_chg': 0.00533936362743602, '62_avg_annual_employee_pct_chg': 0.005602697969759676, '81_avg_annual_employee_pct_chg': 0.005674888177596206, 'travel_time_to_work': 0.005696681245574388, 'birth_45_50_pct': 0.005732195247551425, 'birth_15_19_pct': 0.005766806250496493, '53_avg_annual_pay_pct_chg': 0.0058743552156167, 'household_income': 0.00601950170794561, 'population': 0.006089530609031927, 'birth_30_34_pct': 0.00623680820848603, 'birth_35_39_pct': 0.0062510567177002955, 'birth_40_44_pct': 0.0063686144805655594, 'professional_degree_pct': 0.006448197585790527, 'inventory': 0.006571982973523866, 'birth_25_29_pct': 0.007183702883770154, 'doctorate_degree_pct': 0.007277429082800315, 'birth_20_24_pct': 0.007825613291777288, 'bachelor_degree_pct': 0.008415461177663385, '23_avg_annual_employee_pct_chg': 0.008735749034448185, '99_avg_annual_employee_pct_chg': 0.00965527414075198, 'home_value_median': 0.010870235128651765, 'vacant_units_pct': 0.011106368570914378, '72_avg_annual_employee_pct_chg': 0.011109457432333164, 'hs_diploma_pct': 0.011233046843953848, 'debt_ratio_low': 0.011667140938725383, 'occupied_units_pct': 0.01183256544886853, 'median_ppsf': 0.01189889346624269, 'median_list_ppsf': 0.01200977090300923, 'new_listings': 0.012424972553094491, 'some_college_lessthan_1yr_pct': 0.013299143410474668, 'median_list_price': 0.013467429090966987, 'debt_ratio_high': 0.013629687754709118, 'master_degree_pct': 0.01386165612927052, 'grade12_nodiploma_pct': 0.015129977441248749, 'homes_sold': 0.015577745928293897, 'median_sale_price': 0.016906860006271982, 'vehicles_per_person': 0.01928134640593567, 'some_college_greaterthan_1yr_pct': 0.022796245766055493, 'median_dom': 0.02980218714774276, 'avg_sale_to_list': 0.030472548805665176, 'sold_above_list': 0.03687408025289271, 'corp_income_tax_low': 0.03777371590466716, 'corp_income_tax_high': 0.0514532254390806, 'income_tax_low': 0.05847796088939681, 'GDP': 0.06520480681851921, 'months_of_supply': 0.07877876007515115, 'income_tax_high': 0.10671447845410623}

# %%
d = {'Feature': X.columns, 'Importance': et.feature_importances_}
df = pd.DataFrame(d)
df = df.sort_values(by='Importance', ascending=False).reset_index(drop=True)

fig = px.bar_polar(df.iloc[:30,:], r='Importance', theta='Feature',
            color='Feature', template='plotly_dark',
            color_discrete_sequence=px.colors.sequential.Plasma_r)
fig.show()

# %%
df[df['Importance']>0.0035]
# Out:
#                            Feature  Importance
# 5                  income_tax_high    0.106714
# 49                months_of_supply    0.078779
# 75                             GDP    0.065205
# 4                   income_tax_low    0.058478
# 3             corp_income_tax_high    0.051453
# ..                             ...         ...
# 29       51_avg_annual_pay_pct_chg    0.004102
# 37       71_avg_annual_pay_pct_chg    0.003911
# 39       81_avg_annual_pay_pct_chg    0.003768
# 8   22_avg_annual_employee_pct_chg    0.003725
# 7   21_avg_annual_employee_pct_chg    0.003652
#
# [71 rows x 2 columns]

# %%
pred2019 = et.predict(X_val)


df2019['Predicted_HPI_change'] = pred2019

df2019['Prediction_delta'] = ((df2019['annual_change_pct'] - df2019['Predicted_HPI_change'])/df2019['annual_change_pct'])*100
print(df2019['Prediction_delta'].mean())
#5.5799%
print(df2019['Prediction_delta'].median())
# Out:
# 11.071360602842423
# -8.914948446736185

# %%
fig = px.choropleth(df2019, geojson=counties, locations='county_fips', color='Prediction_delta',
                           color_continuous_scale="Viridis",
                            range_color=(0, 100),
                           scope="usa",
                           labels={'Prediction_delta':'Prediction delta for 2019 HPI'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
