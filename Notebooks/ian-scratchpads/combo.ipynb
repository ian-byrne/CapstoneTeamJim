# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/ianbyrne/Development/CapstoneTeamJim/notebooks/ian-scratchpads/Data/monthly2020_pytorch_targets.csv")

# %%
df1
# Out:
#        Unnamed: 0  county_fips                 region        state  \
# 0               0        10001        Kent County, DE     Delaware
# 1               1        10001        Kent County, DE     Delaware
# 2               2        10001        Kent County, DE     Delaware
# 3               3        10001        Kent County, DE     Delaware
# 4               4        10003  New Castle County, DE     Delaware
# ...           ...          ...                    ...          ...
# 54739       54739         9013     Tolland County, CT  Connecticut
# 54740       54740         9015     Windham County, CT  Connecticut
# 54741       54741         9015     Windham County, CT  Connecticut
# 54742       54742         9015     Windham County, CT  Connecticut
# 54743       54743         9015     Windham County, CT  Connecticut
#
#                    property_type  month    target
# 0                All Residential      0  225000.0
# 1                    Condo/Co-op      0   50000.0
# 2      Single Family Residential      0  235000.0
# 3                      Townhouse      0  158500.0
# 4                All Residential      0  229000.0
# ...                          ...    ...       ...
# 54739  Single Family Residential     11  260000.0
# 54740            All Residential     11  225000.0
# 54741                Condo/Co-op     11  198000.0
# 54742    Multi-Family (2-4 Unit)     11  183000.0
# 54743  Single Family Residential     11  234000.0
#
# [54744 rows x 7 columns]

# %%
df2 = pd.read_csv("/Users/ianbyrne/Development/CapstoneTeamJim/notebooks/ian-scratchpads/Data/monthly2020_pytorch_diff.csv")

# %%
df2
# Out:
#        Unnamed: 0  county_fips                 region        state  \
# 0               0        10001        Kent County, DE     Delaware
# 1               1        10001        Kent County, DE     Delaware
# 2               2        10001        Kent County, DE     Delaware
# 3               3        10001        Kent County, DE     Delaware
# 4               4        10003  New Castle County, DE     Delaware
# ...           ...          ...                    ...          ...
# 54739       54739         9013     Tolland County, CT  Connecticut
# 54740       54740         9015     Windham County, CT  Connecticut
# 54741       54741         9015     Windham County, CT  Connecticut
# 54742       54742         9015     Windham County, CT  Connecticut
# 54743       54743         9015     Windham County, CT  Connecticut
#
#                    property_type  month       target
# 0                All Residential      0    270.26562
# 1                    Condo/Co-op      0 -33141.86000
# 2      Single Family Residential      0     -6.34375
# 3                      Townhouse      0 -20595.48400
# 4                All Residential      0  -7545.71880
# ...                          ...    ...          ...
# 54739  Single Family Residential     11  22882.78100
# 54740            All Residential     11  18437.79700
# 54741                Condo/Co-op     11  20881.78100
# 54742    Multi-Family (2-4 Unit)     11  21185.29700
# 54743  Single Family Residential     11  18492.28100
#
# [54744 rows x 7 columns]

# %%
df2["target"] = df1["target"]

# %%
df2
# Out:
#        Unnamed: 0  county_fips                 region        state  \
# 0               0        10001        Kent County, DE     Delaware
# 1               1        10001        Kent County, DE     Delaware
# 2               2        10001        Kent County, DE     Delaware
# 3               3        10001        Kent County, DE     Delaware
# 4               4        10003  New Castle County, DE     Delaware
# ...           ...          ...                    ...          ...
# 54739       54739         9013     Tolland County, CT  Connecticut
# 54740       54740         9015     Windham County, CT  Connecticut
# 54741       54741         9015     Windham County, CT  Connecticut
# 54742       54742         9015     Windham County, CT  Connecticut
# 54743       54743         9015     Windham County, CT  Connecticut
#
#                    property_type  month    target
# 0                All Residential      0  225000.0
# 1                    Condo/Co-op      0   50000.0
# 2      Single Family Residential      0  235000.0
# 3                      Townhouse      0  158500.0
# 4                All Residential      0  229000.0
# ...                          ...    ...       ...
# 54739  Single Family Residential     11  260000.0
# 54740            All Residential     11  225000.0
# 54741                Condo/Co-op     11  198000.0
# 54742    Multi-Family (2-4 Unit)     11  183000.0
# 54743  Single Family Residential     11  234000.0
#
# [54744 rows x 7 columns]

# %%
df2["preds"] = df2["target"] - df2["diff"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/ianbyrne/Development/CapstoneTeamJim/notebooks/ian-scratchpads/combo.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ianbyrne/Development/CapstoneTeamJim/notebooks/ian-scratchpads/combo.ipynb#ch0000007?line=0'>1</a> df2["preds"] = df2["target"] - df2["diff"]
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///Users/ianbyrne/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'diff'

# %%
df2
# Out:
#        Unnamed: 0  county_fips                 region        state  \
# 0               0        10001        Kent County, DE     Delaware
# 1               1        10001        Kent County, DE     Delaware
# 2               2        10001        Kent County, DE     Delaware
# 3               3        10001        Kent County, DE     Delaware
# 4               4        10003  New Castle County, DE     Delaware
# ...           ...          ...                    ...          ...
# 54667       54667         9013     Tolland County, CT  Connecticut
# 54668       54668         9015     Windham County, CT  Connecticut
# 54669       54669         9015     Windham County, CT  Connecticut
# 54670       54670         9015     Windham County, CT  Connecticut
# 54671       54671         9015     Windham County, CT  Connecticut
#
#                    property_type  month  target-prediction    target  \
# 0                All Residential      0          3968.0625  250000.0
# 1                    Condo/Co-op      0          3747.7734  114000.0
# 2      Single Family Residential      0          6564.6875  265000.0
# 3                      Townhouse      0         -7475.3906  185500.0
# 4                All Residential      0         10050.4220  265000.0
# ...                          ...    ...                ...       ...
# 54667  Single Family Residential     11          5100.7500  284500.0
# 54668            All Residential     11         21730.0310  267000.0
# 54669                Condo/Co-op     11        -31761.1400  177250.0
# 54670    Multi-Family (2-4 Unit)     11         40678.2030  249500.0
# 54671  Single Family Residential     11         13563.4220  270000.0
#
#              preds
# 0      246031.9375
# 1      110252.2266
# 2      258435.3125
# 3      192975.3906
# 4      254949.5780
# ...            ...
# 54667  279399.2500
# 54668  245269.9690
# 54669  209011.1400
# 54670  208821.7970
# 54671  256436.5780
#
# [54672 rows x 9 columns]

# %%
df2.drop(columns="Unnamed: 0", inplace=True)

# %%
df2.rename(columns={"target-prediction": "diff"}, inplace=True)

# %%
df2.to_csv("pytorch_monthly2021_preds.csv")
